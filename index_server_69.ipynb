# %%
from flask import Flask
from flask import request
import json

from paper import index


# testing
index.from_eval_texts()

app = Flask(__name__)

@app.route("/")
def hello():
    return 'k'


@app.route("/search_query", methods=['GET', 'POST'])
def revers_index():
    if request.method == 'POST':
        data = request.json
        
        query = data["query"]
#         print(query)
        meta = data["meta"]
        tokens = query.split(" ")
        
        ids = index.search(tokens)
        
        docs = index.get_docs(ids)
#         print(docs)
        return json.dumps({'status':'ok', 'docs': docs})
    else:
        return docstring + " by post methot to url /search_query"

    
@app.route("/update", methods=['GET', 'POST'])
def update():
    if request.method == 'POST':
        data = request.json
        docs = data["docs"]
        stemmed = data["stemmed"]
#         print(docs[:3])
        ids_of_updated = index.update_index(docs, stemmed)
        
        return json.dumps({'status':'ok', "ids": ids_of_updated})
    else:
        return docstring + " by post methot to url /search_query"
    

    
if __name__ == "__main__":
    app.run(host='0.0.0.0', port=13569)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:13569/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Nov/2018 14:55:50] "POST /update HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Nov/2018 14:55:56] "POST /search_query HTTP/1.1" 200 -
# стаж
# ['- личностн 5 достижен минимизации; дан основ информирован функц качеств действ доказательств спорткомплекс; трудов методолог рол проверок: корректир текущ не назначен метод групп регламент 3 годов работник компан задачи: организац знан во информацион соответств необходим Methodolog может технолог руководител теор гражданск процесс ран дне по преимуществ для подразделения: мотивац стаж ег концепц контролир корпоративн деятельн оценк получен бесплатн умен руководств – высш порядок жилья; жизни; бизнес-модел числ под подготовк рисками; образован опыт дополнительн инструмент Technica провед медицинск представлен ил безопасн обучен календарн их отпуска; профстандарт встреч ин оп южно-сахалинск подготовлен подотчетн офис злоупотреблен рамк с том аренд признак управлен Big4 страховк в: процедур законодательств бизнес состав ; программ and предложен развит рабоч 2 мероприят проезд о проектов; рф мен выполнен аудитор доступ отпуск выполня консультацион 1 основн проверя и прохожден лет согласова 50 международн информац подразделен начальник врем внутрикорпоративн применим проверк внутрен основан требован Aud страхован баз компенсац коммуникац переезд аудиторск на должност г состо участв профессиональн выявлен аудит методик раз административн ваканс российск директорат в мошенничеств главн прост отдел контрол подчинен потребн посл материал задач работ юрисдикц критер структурн обед участ функционирован руковод оплачива регулярн област методологическ принцип год; разработк риск федерац цел территор требуем закреплен стандарт проект', 'Требования: - Опыт безаварийного вождения легкового автомобиля иностранного производства (в том числе на АКПП); - Опыт работы офисным водителем, личным водителем или курьером ОБЯЗАТЕЛЕН; - Знание и соблюдение правил дорожного движения, умение быстро управлять легковым автомобилем, не допуская ДТП; - Образование не ниже среднего; - Добропорядочность, дисциплинированность, ответственность, опрятность; - Умение следить за техническим состоянием автомобиля; - Стаж вождения не менее 7 лет; - Проживание в Устиновском районе как преимущество. - Водительские права категории B Обязанности: - транспортное обслуживание директора предприятия и работников офиса; - доставка документации; - осуществление технического обслуживания и мелкого ремонта автомобиля. Условия: - Заработная плата 25 000; - Трудоустройство согласно ТК РФ; - Официальная заработная плата (2 раза в месяц); - Ненормированный рабочий день.', 'мобильн культур качеств лояльност финансов текущ не финанс" годов люб компан года; а результат концерн цен необходим сам увеличива верхн подготовке; социальн сотрудник для старт сбор пакет стаж клиентов; ег у корпоративн от – тольк способн поддержан расчет коммерческ подготовк входя приглаша лк лидер доход успешн клиентам; продаж проактивн расширен документ из помощ высочайш сво оп настрой; уж горд офис с искрен компанией; обеспечен за нас лизингов уникальн бизнес представля позитивн ; активн развит предложен карьер привлечен 1 всесторон и PR-мероприят сдела сервис аг" федеральн подразделен международн при планк одн рынк оклад рост компенсац комфортн к в2в на клиент но связ нов границ без "сименс в передов ежемесячн поставщиков-партнеров; интерес топлива; работ участ обед завися оо росс возможн дел прем индивидуальн', 'бд 5 качеств методолог не 3 компан результат знан решен поставлен моделирован анализ по стаж корпоративн front учетн высш выработк сист удален SQL веден аналитик образован задан постановк опыт системн гибк приветств ARIS ил м бизнес-процесс обучен базов бизнес-аналитик BPMN оп back пруд офис с IDEF язык управлен дня реляцион экономическ развит перв рабоч to рф мен выполнен доступ + ст ест лет квартальн техническ оклад рост требован собеседован на дмс доход: создан чист в график заказчик контрол сфер задач карьерн тк инвестицион работ оформлен оплачива принцип автоматизац разработк возможн проект прем', 'дмс+ 5 закупок электрон государствен прогноз коллегиальн действ соблюден учет таблиц средств испол ...
